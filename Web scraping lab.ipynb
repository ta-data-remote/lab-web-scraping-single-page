# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'http://www.popvortex.com/music/charts/top-100-songs.php'

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
#soup

# %%
soup.select('#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p')
# Out:
# [<p class="title-artist"><cite class="title">81 Million Votes, My Ass</cite><em class="artist">The Truth Bombers &amp; Kari Lake</em></p>]

# %%
soup.select("p.title-artist")
soup.select("p")[1].get_text()
# Out:
# 'The chart of the current best selling hot 100 song downloads on iTunes right now is updated daily and is for the top singles in the USA.'

# %%
soup.select('#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p > em')[0].get_text()
# Out:
# 'The Truth Bombers & Kari Lake'

# %%
soup.select('#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p > cite')[0].get_text()
# Out:
# '81 Million Votes, My Ass'

# %%
soup.select("p.title-artist")[0]
soup.select("p.title-artist")[0].get_text()
# Out:
# '81 Million Votes, My AssThe Truth Bombers & Kari Lake'

# %%
title = []
artist = []

# define the number of iterations of our for loop
# by checking how many elements are in the retrieved result set
# (this is equivalent but more robust than just explicitly defining 250 iterations)
num_iter = len(soup.select("div.chart-content.col-xs-12.col-sm-8 > p"))

artistlist = soup.select("div.chart-content.col-xs-12.col-sm-8 > p > em")
songlist = soup.select('div.chart-content.col-xs-12.col-sm-8 > p > cite')

#iterate through the result set and retrive all the data
for i in range(num_iter):
    title.append(songlist[i].get_text())
    artist.append(artistlist[i].get_text())

print(title)
print(artist)
# Out:
# ['81 Million Votes, My Ass', 'Fast Car', 'Last Night', 'Take Two', 'Need A Favor', 'Save Me (with Lainey Wilson)', 'Flowers', 'Bust a Move', 'Thank God I Do', 'Son', 'Calm Down', 'Let Me In', 'Thinkin’ Bout Me', 'Funky Cold Medina', 'Stand By Me (feat. Morgan Wallen)', 'Son Of A Sinner', 'Dance The Night', 'Area Codes', 'All My Life (feat. J. Cole)', 'Pound Town 2', 'Wild Thing', 'TRUSTFALL', 'Thank God', 'Thicc As Thieves', 'Cruel Summer', 'Favorite Song', 'Eyes Closed', 'Heart Like A Truck', 'Love You Anyway', 'Religiously', 'Thought You Should Know', 'Dancin’ In The Country', 'Tennessee Orange', 'Praise You Anywhere', "Something in the Orange (Z&E's Version)", 'Rode Hard', 'Karma', 'Can She Have This Dance', 'Heaven', 'Rock and A Hard Place', 'Anti-Hero', 'Next Thing You Know', 'Watermelon Moonshine', 'Mourning', 'Daylight', 'Fast Car', 'Unstoppable', 'Bury Me in Georgia (Single Edit)', 'wait in the truck', 'One Thing At A Time', 'If You Were Mine', 'Chemical', 'Oklahoma Smokeshow', 'Am I Dreaming', 'Tennessee Whiskey', 'Euphoria', 'Wasted On You', 'Peaches', 'Hip Hop Hooray (Re-recorded Version)', 'Sure Thing', 'VULGAR', 'Waffle House', 'Try That In A Small Town', 'Makeba', 'TRUCK BED', 'O.P.P. (Re-recorded Version)', 'Drinkaby', 'Shivers', "I Ain't Worried", 'Ella Baila Sola', 'Dial Drunk', 'Gratitude', 'Halfway To Hell', 'Cupid (Twin Ver.)', 'WHERE SHE GOES', 'Karma (feat. Ice Spice)', 'To the Bar', 'Memory Lane', 'Take Me Out', 'Your Heart Or Mine', 'Sugar Babies', 'Hits Different', 'Standing Room Only', 'One Margarita (Margarita Song)', 'You Need To Calm Down', 'You Proof', 'But I Got A Beer In My Hand', 'Life Goes On (feat. Luke Combs)', 'red flag collector', 'Perfect', 'Whiskey Glasses', 'Holy Forever', 'Put It On Da Floor Again (feat. Cardi B)', 'Slut Me Out', 'A Symptom Of Being Human', 'She Had Me At Heads Carolina', 'How Do I Say Goodbye', 'Calm Down', 'PLEBADA']
# ['The Truth Bombers & Kari Lake', 'Luke Combs', 'Morgan Wallen', 'BTS', 'Jelly Roll', 'Jelly Roll', 'Miley Cyrus', 'Young MC', 'Lauren Daigle', 'Mitch Rossell', 'Rema & Selena Gomez', 'EXO', 'Morgan Wallen', 'Tone-Loc', 'Lil Durk', 'Jelly Roll', 'Dua Lipa', 'Kali', 'Lil Durk', 'Sexyy Red, Nicki Minaj & Tay Keith', 'Tone-Loc', 'P!nk', 'Kane Brown & Katelyn Brown', 'Lauren Alaina & Lainey Wilson', 'Taylor Swift', 'Toosii', 'Ed Sheeran', 'Lainey Wilson', 'Luke Combs', 'Bailey Zimmerman', 'Morgan Wallen', 'Tyler Hubbard', 'Megan Moroney', 'Brandon Lake', 'Zach Bryan', 'Danae Hays', 'Taylor Swift', 'Drew Baldridge', 'Niall Horan', 'Bailey Zimmerman', 'Taylor Swift', 'Jordan Davis', 'Lainey Wilson', 'Post Malone', 'David Kushner', 'Tracy Chapman', 'Sia', 'Kane Brown', 'HARDY & Lainey Wilson', 'Morgan Wallen', 'Miranda Lambert & Leon Bridges', 'Post Malone', 'Zach Bryan', 'Metro Boomin, A$AP Rocky & Roisee', 'Chris Stapleton', 'BTS', 'Morgan Wallen', 'Jack Black', 'Naughty By Nature', 'Miguel', 'Sam Smith & Madonna', 'Jonas Brothers', 'Jason Aldean', 'Jain', 'HARDY', 'Naughty By Nature', 'Cole Swindell', 'Ed Sheeran', 'OneRepublic', 'Eslabon Armado & Peso Pluma', 'Noah Kahan', 'Brandon Lake', 'Jelly Roll', 'FIFTY FIFTY', 'Bad Bunny', 'Taylor Swift', 'Cooper Alan', 'Old Dominion', 'Carrie Underwood', 'Jon Pardi', 'Spoon', 'Taylor Swift', 'Tim McGraw', 'That Chick Angel, Casa Di & Steve Terrell', 'Taylor Swift', 'Morgan Wallen', 'Luke Bryan', 'Ed Sheeran', 'Kelly Clarkson', 'Ed Sheeran', 'Morgan Wallen', 'Chris Tomlin', 'Latto', 'NLE Choppa', 'Shinedown', 'Cole Swindell', 'Dean Lewis', 'Rema', 'El Alfa & Peso Pluma']

# %%
import pandas as pd

# %%
songs = pd.DataFrame({"title":title,"artist":artist})

# %%
songs.head(100)
# Out:
#                            title                         artist
# 0       81 Million Votes, My Ass  The Truth Bombers & Kari Lake
# 1                       Fast Car                     Luke Combs
# 2                     Last Night                  Morgan Wallen
# 3                       Take Two                            BTS
# 4                   Need A Favor                     Jelly Roll
# ..                           ...                            ...
# 94      A Symptom Of Being Human                      Shinedown
# 95  She Had Me At Heads Carolina                  Cole Swindell
# 96          How Do I Say Goodbye                     Dean Lewis
# 97                     Calm Down                           Rema
# 98                       PLEBADA           El Alfa & Peso Pluma
#
# [99 rows x 2 columns]

# %%
url1 = 'https://www.billboard.com/charts/greatest-hot-100-singles/'

# %%
response1 = requests.get(url1)
response1.status_code
# Out:
# 200

# %%
soup1 = BeautifulSoup(response1.content, "html.parser")

# %%
#soup1

# %%
#print(soup1.prettify())

# %%
soup1.select('#title-of-a-story')
# Out:
# [<h3 class="c-title a-font-primary-bold-xxl a-font-primary-bold-l@mobile-max u-font-size-45@desktop" id="title-of-a-story">
#
#
#
#
#  					Blinding Lights
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					The Twist
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Smooth
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Mack The Knife
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Uptown Funk!
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					How Do I Live
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Party Rock Anthem
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I Gotta Feeling
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Macarena (Bayside Boys Mix)
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Shape Of You
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Physical
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					You Light Up My Life
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Hey Jude
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Closer
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					We Belong Together
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Un-Break My Heart
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Yeah!
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Bette Davis Eyes
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Circles
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Endless Love
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Tonight's The Night (Gonna Be Alright)
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Foolish Games/You Were Meant For Me
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					(Everything I Do) I Do It For You
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I'Ll Make Love To You
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					The Theme From "A Summer Place"
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Le Freak
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					How Deep Is Your Love
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Eye Of The Tiger
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					We Found Love
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Girls Like You
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Low
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Levitating
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I Just Want To Be Your Everything
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Too Close
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Every Breath You Take
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Somebody That I Used To Know
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Despacito
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Flashdance...What A Feeling
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Rolling In The Deep
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Tossin' And Turnin'
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Old Town Road
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					The Battle Of New Orleans
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					One Sweet Day
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Truly Madly Deeply
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Silly Love Songs
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Let's Get It On
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Night Fever
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Another One Bites The Dust
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Mood
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Say Say Say
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					How You Remind Me
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Tie A Yellow Ribbon Round The Ole Oak Tree
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					It's All In The Game
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I Want To Hold Your Hand
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Shadow Dancing
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Call Me Maybe
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Blurred Lines
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Candle In The Wind 1997/Something About The Way You Look Tonight
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					No One
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I Will Always Love You
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					End Of The Road
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Perfect
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Boom Boom Pow
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Call Me
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Let Me Love You
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Stayin' Alive
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Lady
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Tik Tok
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I'm A Believer
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Gold Digger
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Apologize
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					The Sign
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Centerfold
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					All About That Bass
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Sunflower (Spider-Man: Into The Spider-Verse)
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					(Just Like) Starting Over
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Royals
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					The Boy Is Mine
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Because I Love You (The Postman Song)
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I Love Rock 'N Roll
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Aquarius/Let The Sunshine In (The Flesh Failures)
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Whoomp! (There It Is)
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					God's Plan
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Moves Like Jagger
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Ebony And Ivory
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Rush Rush
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					That's What Friends Are For
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Happy
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Upside Down
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Sugar, Sugar
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Just The Way You Are
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Dilemma
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I Heard It Through The Grapevine
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					You're Still The One
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Billie Jean
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Hot Stuff
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Rockstar
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Gangsta's Paradise
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Abracadabra
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					You're So Vain
#
#  </h3>,
#  <h3 class="c-title a-font-primary-medium-xs u-letter-spacing-0026 lrv-u-margin-b-075 u-min-height-36" id="title-of-a-story">
#
#
#
#
#  					Bryan Cranston Says He'll Shut Down Production Company, Sell Half of Mezcal Brand by 2026: "I Want to Change the Paradigm"
#
#  </h3>,
#  <h3 class="c-title a-font-primary-medium-xs u-letter-spacing-0026 lrv-u-margin-b-075 u-min-height-36" id="title-of-a-story">
#
#
#
#
#  					Ivanka Trump &amp; Jared Kushner's Reportedly Shady Finances Are Being Called Out by This Former Donald Trump Ally
#
#  </h3>,
#  <h3 class="c-title a-font-primary-medium-xs u-letter-spacing-0026 lrv-u-margin-b-075 u-min-height-36" id="title-of-a-story">
#
#
#
#
#  					NFL Star Patrick Mahomes Lists Renovated Missouri Ranch House
#
#  </h3>,
#  <h3 class="c-title a-font-primary-medium-xs u-letter-spacing-0026 lrv-u-margin-b-075 u-min-height-36" id="title-of-a-story">
#
#
#
#
#  					Snoop Dogg Responds To Island Boy Threatening To "Beat His A**"
#
#  </h3>,
#  <h3 class="c-title a-font-primary-medium-xs u-letter-spacing-0026 lrv-u-margin-b-075" id="title-of-a-story">
#
#
#
#
#  					‘Avatar 3’ Pushed a Year to 2025, Two ‘Star Wars’ Movies Head for 2026 and ‘Avengers’ Films Delayed
#
#  </h3>,
#  <h3 class="c-title a-font-primary-medium-xs u-letter-spacing-0026 lrv-u-margin-b-075" id="title-of-a-story">
#
#
#
#
#  					Doechii Puts Her Twist On Beyoncé’s “AMERICA HAS A PROBLEM”
#
#  </h3>,
#  <h3 class="c-title a-font-primary-medium-xs u-letter-spacing-0026 lrv-u-margin-b-075" id="title-of-a-story">
#
#
#
#
#  					Metavelso by Clandestina, a Cuban Brand, Opens at The Westfield World Trade Center
#
#  </h3>,
#  <h3 class="c-title a-font-primary-medium-xs u-letter-spacing-0026 lrv-u-margin-b-075" id="title-of-a-story">
#
#
#
#
#  					Man United Stock Soars on Unconfirmed Report of Qatari Winning Bid
#
#  </h3>,
#  <h3 class="c-title a-font-primary-medium-xs u-letter-spacing-0026 lrv-u-margin-b-075" id="title-of-a-story">
#
#
#
#
#  					Paul McCartney Used AI to Make a Final Beatles Song — But Not in a Creepy Way
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-m lrv-u-line-height-copy lrv-u-margin-r-1 lrv-u-text-align-center@mobile-max lrv-u-padding-b-050@mobile-max lrv-u-margin-r-00@mobile-max" id="title-of-a-story">
#
#
#
#
#  					Follow Us
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-m" id="title-of-a-story">
#
#
#
#
#  					Have a Tip?
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-m u-margin-r-075@tablet lrv-u-margin-b-00" id="title-of-a-story">
#
#
#
#
#  					The Daily
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-m" id="title-of-a-story">
#
#
#
#
#  					Have a Tip?
#
#  </h3>]

# %%
soup1.select("h3.title-of-a-story")
soup1.select("h3")[0].get_text(strip=True)
# Out:
# 'Blinding Lights'

# %%
artist_list1 = soup1.select("ul > li.lrv-u-width-100p > ul > li.o-chart-results-list__item.\/\/.lrv-u-flex-grow-1.lrv-u-flex.lrv-u-flex-direction-column.lrv-u-justify-content-center.lrv-u-border-b-1.lrv-u-border-color-grey-light.lrv-u-padding-l-2.lrv-u-padding-r-1.lrv-u-padding-l-1\@mobile-max > span")
artist_list1
# Out:
# [<span class="c-label">
#
#  	The Weeknd
#  </span>,
#  <span class="c-label">
#
#  	Chubby Checker
#  </span>,
#  <span class="c-label">
#
#  	Santana Featuring Rob Thomas
#  </span>,
#  <span class="c-label">
#
#  	Bobby Darin
#  </span>,
#  <span class="c-label">
#
#  	Mark Ronson Featuring Bruno Mars
#  </span>,
#  <span class="c-label">
#
#  	LeAnn Rimes
#  </span>,
#  <span class="c-label">
#
#  	LMFAO Featuring Lauren Bennett &amp; GoonRock
#  </span>,
#  <span class="c-label">
#
#  	The Black Eyed Peas
#  </span>,
#  <span class="c-label">
#
#  	Los Del Rio
#  </span>,
#  <span class="c-label">
#
#  	Ed Sheeran
#  </span>,
#  <span class="c-label">
#
#  	Olivia Newton-John
#  </span>,
#  <span class="c-label">
#
#  	Debby Boone
#  </span>,
#  <span class="c-label">
#
#  	The Beatles
#  </span>,
#  <span class="c-label">
#
#  	The Chainsmokers Featuring Halsey
#  </span>,
#  <span class="c-label">
#
#  	Mariah Carey
#  </span>,
#  <span class="c-label">
#
#  	Toni Braxton
#  </span>,
#  <span class="c-label">
#
#  	Usher Featuring Lil Jon &amp; Ludacris
#  </span>,
#  <span class="c-label">
#
#  	Kim Carnes
#  </span>,
#  <span class="c-label">
#
#  	Post Malone
#  </span>,
#  <span class="c-label">
#
#  	Diana Ross &amp; Lionel Richie
#  </span>,
#  <span class="c-label">
#
#  	Rod Stewart
#  </span>,
#  <span class="c-label">
#
#  	Jewel
#  </span>,
#  <span class="c-label">
#
#  	Bryan Adams
#  </span>,
#  <span class="c-label">
#
#  	Boyz II Men
#  </span>,
#  <span class="c-label">
#
#  	Percy Faith And His Orchestra
#  </span>,
#  <span class="c-label">
#
#  	Chic
#  </span>,
#  <span class="c-label">
#
#  	Bee Gees
#  </span>,
#  <span class="c-label">
#
#  	Survivor
#  </span>,
#  <span class="c-label">
#
#  	Rihanna Featuring Calvin Harris
#  </span>,
#  <span class="c-label">
#
#  	Maroon 5 Featuring Cardi B
#  </span>,
#  <span class="c-label">
#
#  	Flo Rida Featuring T-Pain
#  </span>,
#  <span class="c-label">
#
#  	Dua Lipa
#  </span>,
#  <span class="c-label">
#
#  	Andy Gibb
#  </span>,
#  <span class="c-label">
#
#  	Next
#  </span>,
#  <span class="c-label">
#
#  	The Police
#  </span>,
#  <span class="c-label">
#
#  	Gotye Featuring Kimbra
#  </span>,
#  <span class="c-label">
#
#  	Luis Fonsi &amp; Daddy Yankee Featuring Justin Bieber
#  </span>,
#  <span class="c-label">
#
#  	Irene Cara
#  </span>,
#  <span class="c-label">
#
#  	Adele
#  </span>,
#  <span class="c-label">
#
#  	Bobby Lewis
#  </span>,
#  <span class="c-label">
#
#  	Lil Nas X Featuring Billy Ray Cyrus
#  </span>,
#  <span class="c-label">
#
#  	Johnny Horton
#  </span>,
#  <span class="c-label">
#
#  	Mariah Carey &amp; Boyz II Men
#  </span>,
#  <span class="c-label">
#
#  	Savage Garden
#  </span>,
#  <span class="c-label">
#
#  	Wings
#  </span>,
#  <span class="c-label">
#
#  	Marvin Gaye
#  </span>,
#  <span class="c-label">
#
#  	Bee Gees
#  </span>,
#  <span class="c-label">
#
#  	Queen
#  </span>,
#  <span class="c-label">
#
#  	24kGoldn Featuring iann dior
#  </span>,
#  <span class="c-label">
#
#  	Paul McCartney And Michael Jackson
#  </span>,
#  <span class="c-label">
#
#  	Nickelback
#  </span>,
#  <span class="c-label">
#
#  	Dawn Featuring Tony Orlando
#  </span>,
#  <span class="c-label">
#
#  	Tommy Edwards
#  </span>,
#  <span class="c-label">
#
#  	The Beatles
#  </span>,
#  <span class="c-label">
#
#  	Andy Gibb
#  </span>,
#  <span class="c-label">
#
#  	Carly Rae Jepsen
#  </span>,
#  <span class="c-label">
#
#  	Robin Thicke Featuring T.I. + Pharrell
#  </span>,
#  <span class="c-label">
#
#  	Elton John
#  </span>,
#  <span class="c-label">
#
#  	Alicia Keys
#  </span>,
#  <span class="c-label">
#
#  	Whitney Houston
#  </span>,
#  <span class="c-label">
#
#  	Boyz II Men
#  </span>,
#  <span class="c-label">
#
#  	Ed Sheeran
#  </span>,
#  <span class="c-label">
#
#  	The Black Eyed Peas
#  </span>,
#  <span class="c-label">
#
#  	Blondie
#  </span>,
#  <span class="c-label">
#
#  	Mario
#  </span>,
#  <span class="c-label">
#
#  	Bee Gees
#  </span>,
#  <span class="c-label">
#
#  	Kenny Rogers
#  </span>,
#  <span class="c-label">
#
#  	Ke$ha
#  </span>,
#  <span class="c-label">
#
#  	The Monkees
#  </span>,
#  <span class="c-label">
#
#  	Kanye West Featuring Jamie Foxx
#  </span>,
#  <span class="c-label">
#
#  	Timbaland Featuring OneRepublic
#  </span>,
#  <span class="c-label">
#
#  	Ace Of Base
#  </span>,
#  <span class="c-label">
#
#  	The J. Geils Band
#  </span>,
#  <span class="c-label">
#
#  	Meghan Trainor
#  </span>,
#  <span class="c-label">
#
#  	Post Malone &amp; Swae Lee
#  </span>,
#  <span class="c-label">
#
#  	John Lennon
#  </span>,
#  <span class="c-label">
#
#  	Lorde
#  </span>,
#  <span class="c-label">
#
#  	Brandy &amp; Monica
#  </span>,
#  <span class="c-label">
#
#  	Stevie B
#  </span>,
#  <span class="c-label">
#
#  	Joan Jett &amp; The Blackhearts
#  </span>,
#  <span class="c-label">
#
#  	The 5th Dimension
#  </span>,
#  <span class="c-label">
#
#  	Tag Team
#  </span>,
#  <span class="c-label">
#
#  	Drake
#  </span>,
#  <span class="c-label">
#
#  	Maroon 5 Featuring Christina Aguilera
#  </span>,
#  <span class="c-label">
#
#  	Paul McCartney And Stevie Wonder
#  </span>,
#  <span class="c-label">
#
#  	Paula Abdul
#  </span>,
#  <span class="c-label">
#
#  	Dionne &amp; Friends Featuring Elton John, Gladys Knight And Stevie Wonder
#  </span>,
#  <span class="c-label">
#
#  	Pharrell Williams
#  </span>,
#  <span class="c-label">
#
#  	Diana Ross
#  </span>,
#  <span class="c-label">
#
#  	The Archies
#  </span>,
#  <span class="c-label">
#
#  	Bruno Mars
#  </span>,
#  <span class="c-label">
#
#  	Nelly Featuring Kelly Rowland
#  </span>,
#  <span class="c-label">
#
#  	Marvin Gaye
#  </span>,
#  <span class="c-label">
#
#  	Shania Twain
#  </span>,
#  <span class="c-label">
#
#  	Michael Jackson
#  </span>,
#  <span class="c-label">
#
#  	Donna Summer
#  </span>,
#  <span class="c-label">
#
#  	Post Malone Featuring 21 Savage
#  </span>,
#  <span class="c-label">
#
#  	Coolio Featuring L.V.
#  </span>,
#  <span class="c-label">
#
#  	The Steve Miller Band
#  </span>,
#  <span class="c-label">
#
#  	Carly Simon
#  </span>]

# %%
title_list1 = soup1.select("ul > li.lrv-u-width-100p > ul > li.o-chart-results-list__item.\/\/.lrv-u-flex-grow-1.lrv-u-flex.lrv-u-flex-direction-column.lrv-u-justify-content-center.lrv-u-border-b-1.lrv-u-border-color-grey-light.lrv-u-padding-l-2.lrv-u-padding-r-1.lrv-u-padding-l-1\@mobile-max h3")
title_list1
# Out:
# [<h3 class="c-title a-font-primary-bold-xxl a-font-primary-bold-l@mobile-max u-font-size-45@desktop" id="title-of-a-story">
#
#
#
#
#  					Blinding Lights
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					The Twist
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Smooth
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Mack The Knife
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Uptown Funk!
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					How Do I Live
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Party Rock Anthem
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I Gotta Feeling
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Macarena (Bayside Boys Mix)
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Shape Of You
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Physical
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					You Light Up My Life
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Hey Jude
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Closer
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					We Belong Together
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Un-Break My Heart
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Yeah!
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Bette Davis Eyes
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Circles
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Endless Love
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Tonight's The Night (Gonna Be Alright)
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Foolish Games/You Were Meant For Me
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					(Everything I Do) I Do It For You
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I'Ll Make Love To You
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					The Theme From "A Summer Place"
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Le Freak
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					How Deep Is Your Love
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Eye Of The Tiger
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					We Found Love
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Girls Like You
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Low
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Levitating
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I Just Want To Be Your Everything
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Too Close
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Every Breath You Take
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Somebody That I Used To Know
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Despacito
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Flashdance...What A Feeling
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Rolling In The Deep
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Tossin' And Turnin'
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Old Town Road
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					The Battle Of New Orleans
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					One Sweet Day
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Truly Madly Deeply
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Silly Love Songs
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Let's Get It On
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Night Fever
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Another One Bites The Dust
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Mood
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Say Say Say
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					How You Remind Me
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Tie A Yellow Ribbon Round The Ole Oak Tree
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					It's All In The Game
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I Want To Hold Your Hand
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Shadow Dancing
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Call Me Maybe
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Blurred Lines
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Candle In The Wind 1997/Something About The Way You Look Tonight
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					No One
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I Will Always Love You
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					End Of The Road
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Perfect
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Boom Boom Pow
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Call Me
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Let Me Love You
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Stayin' Alive
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Lady
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Tik Tok
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I'm A Believer
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Gold Digger
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Apologize
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					The Sign
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Centerfold
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					All About That Bass
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Sunflower (Spider-Man: Into The Spider-Verse)
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					(Just Like) Starting Over
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Royals
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					The Boy Is Mine
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Because I Love You (The Postman Song)
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I Love Rock 'N Roll
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Aquarius/Let The Sunshine In (The Flesh Failures)
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Whoomp! (There It Is)
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					God's Plan
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Moves Like Jagger
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Ebony And Ivory
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Rush Rush
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					That's What Friends Are For
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Happy
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Upside Down
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Sugar, Sugar
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Just The Way You Are
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Dilemma
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					I Heard It Through The Grapevine
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					You're Still The One
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Billie Jean
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Hot Stuff
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Rockstar
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Gangsta's Paradise
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					Abracadabra
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-l" id="title-of-a-story">
#
#
#
#
#  					You're So Vain
#
#  </h3>]

# %%
title1 = []
artist1 = []

# define the number of iterations of our for loop
# by checking how many elements are in the retrieved result set
# (this is equivalent but more robust than just explicitly defining 250 iterations)

num_iter = len(artist_list1)

for i in range(num_iter):
    title1.append(title_list1[i].get_text(strip=True))
    artist1.append(artist_list1[i].get_text(strip=True))

print(title1)
print(artist1)
# Out:
# ['Blinding Lights', 'The Twist', 'Smooth', 'Mack The Knife', 'Uptown Funk!', 'How Do I Live', 'Party Rock Anthem', 'I Gotta Feeling', 'Macarena (Bayside Boys Mix)', 'Shape Of You', 'Physical', 'You Light Up My Life', 'Hey Jude', 'Closer', 'We Belong Together', 'Un-Break My Heart', 'Yeah!', 'Bette Davis Eyes', 'Circles', 'Endless Love', "Tonight's The Night (Gonna Be Alright)", 'Foolish Games/You Were Meant For Me', '(Everything I Do) I Do It For You', "I'Ll Make Love To You", 'The Theme From "A Summer Place"', 'Le Freak', 'How Deep Is Your Love', 'Eye Of The Tiger', 'We Found Love', 'Girls Like You', 'Low', 'Levitating', 'I Just Want To Be Your Everything', 'Too Close', 'Every Breath You Take', 'Somebody That I Used To Know', 'Despacito', 'Flashdance...What A Feeling', 'Rolling In The Deep', "Tossin' And Turnin'", 'Old Town Road', 'The Battle Of New Orleans', 'One Sweet Day', 'Truly Madly Deeply', 'Silly Love Songs', "Let's Get It On", 'Night Fever', 'Another One Bites The Dust', 'Mood', 'Say Say Say', 'How You Remind Me', 'Tie A Yellow Ribbon Round The Ole Oak Tree', "It's All In The Game", 'I Want To Hold Your Hand', 'Shadow Dancing', 'Call Me Maybe', 'Blurred Lines', 'Candle In The Wind 1997/Something About The Way You Look Tonight', 'No One', 'I Will Always Love You', 'End Of The Road', 'Perfect', 'Boom Boom Pow', 'Call Me', 'Let Me Love You', "Stayin' Alive", 'Lady', 'Tik Tok', "I'm A Believer", 'Gold Digger', 'Apologize', 'The Sign', 'Centerfold', 'All About That Bass', 'Sunflower (Spider-Man: Into The Spider-Verse)', '(Just Like) Starting Over', 'Royals', 'The Boy Is Mine', 'Because I Love You (The Postman Song)', "I Love Rock 'N Roll", 'Aquarius/Let The Sunshine In (The Flesh Failures)', 'Whoomp! (There It Is)', "God's Plan", 'Moves Like Jagger', 'Ebony And Ivory', 'Rush Rush', "That's What Friends Are For", 'Happy', 'Upside Down', 'Sugar, Sugar', 'Just The Way You Are', 'Dilemma', 'I Heard It Through The Grapevine', "You're Still The One", 'Billie Jean', 'Hot Stuff', 'Rockstar', "Gangsta's Paradise", 'Abracadabra', "You're So Vain"]
# ['The Weeknd', 'Chubby Checker', 'Santana Featuring Rob Thomas', 'Bobby Darin', 'Mark Ronson Featuring Bruno Mars', 'LeAnn Rimes', 'LMFAO Featuring Lauren Bennett & GoonRock', 'The Black Eyed Peas', 'Los Del Rio', 'Ed Sheeran', 'Olivia Newton-John', 'Debby Boone', 'The Beatles', 'The Chainsmokers Featuring Halsey', 'Mariah Carey', 'Toni Braxton', 'Usher Featuring Lil Jon & Ludacris', 'Kim Carnes', 'Post Malone', 'Diana Ross & Lionel Richie', 'Rod Stewart', 'Jewel', 'Bryan Adams', 'Boyz II Men', 'Percy Faith And His Orchestra', 'Chic', 'Bee Gees', 'Survivor', 'Rihanna Featuring Calvin Harris', 'Maroon 5 Featuring Cardi B', 'Flo Rida Featuring T-Pain', 'Dua Lipa', 'Andy Gibb', 'Next', 'The Police', 'Gotye Featuring Kimbra', 'Luis Fonsi & Daddy Yankee Featuring Justin Bieber', 'Irene Cara', 'Adele', 'Bobby Lewis', 'Lil Nas X Featuring Billy Ray Cyrus', 'Johnny Horton', 'Mariah Carey & Boyz II Men', 'Savage Garden', 'Wings', 'Marvin Gaye', 'Bee Gees', 'Queen', '24kGoldn Featuring iann dior', 'Paul McCartney And Michael Jackson', 'Nickelback', 'Dawn Featuring Tony Orlando', 'Tommy Edwards', 'The Beatles', 'Andy Gibb', 'Carly Rae Jepsen', 'Robin Thicke Featuring T.I. + Pharrell', 'Elton John', 'Alicia Keys', 'Whitney Houston', 'Boyz II Men', 'Ed Sheeran', 'The Black Eyed Peas', 'Blondie', 'Mario', 'Bee Gees', 'Kenny Rogers', 'Ke$ha', 'The Monkees', 'Kanye West Featuring Jamie Foxx', 'Timbaland Featuring OneRepublic', 'Ace Of Base', 'The J. Geils Band', 'Meghan Trainor', 'Post Malone & Swae Lee', 'John Lennon', 'Lorde', 'Brandy & Monica', 'Stevie B', 'Joan Jett & The Blackhearts', 'The 5th Dimension', 'Tag Team', 'Drake', 'Maroon 5 Featuring Christina Aguilera', 'Paul McCartney And Stevie Wonder', 'Paula Abdul', 'Dionne & Friends Featuring Elton John, Gladys Knight And Stevie Wonder', 'Pharrell Williams', 'Diana Ross', 'The Archies', 'Bruno Mars', 'Nelly Featuring Kelly Rowland', 'Marvin Gaye', 'Shania Twain', 'Michael Jackson', 'Donna Summer', 'Post Malone Featuring 21 Savage', 'Coolio Featuring L.V.', 'The Steve Miller Band', 'Carly Simon']

# %%
billboard = pd.DataFrame({"title":title1,"artist":artist1})

# %%
billboard.head()
# Out:
#              title                            artist
# 0  Blinding Lights                        The Weeknd
# 1        The Twist                    Chubby Checker
# 2           Smooth      Santana Featuring Rob Thomas
# 3   Mack The Knife                       Bobby Darin
# 4     Uptown Funk!  Mark Ronson Featuring Bruno Mars

# %%
def recommend_song(song):
    index = billboard[billboard['title'] == song].index
    
    if len(index) == 0:
        print("No recommendation")
    else:
        filtered_songs = songs[songs.index != index[0]]
        
        if len(filtered_songs) == 0:
            print("No recommendation")
        else:
            recommended_song = filtered_songs.sample(n=1)
            recommended_title = recommended_song['title'].values[0]
            recommended_artist = recommended_song['artist'].values[0]
            print("Recommended song:", recommended_title, "by", recommended_artist)

# %%
input_song = input("Enter a song title: ")
recommend_song(input_song)
# Out:
# Enter a song title: Smooth
# Recommended song: Cruel Summer by Taylor Swift
